# %% [markdown]
# # A First Look at Model Output
#
# This notebook serves as a demo for taking a first look at model output. This example is shown for my Antarctica Temperature regional model. You can follow and/or adapt this notebook based on your configuration
#
# First, import packages to visualize the model fields here:

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Next, define the location of the run directory for the model. This directory should live next to the directory where your input directory is located.

# %%
# define the run directory
run_dir = '/Users/eddie/Documents/CS185C/Project/run'

# %% [markdown]
# ## Downloading a file
# Your model should be implemented with output for a variety of model fields. In this notebook, let's just download one so we can see how the model is performing. In my model, we output daily snapshots of surface temperature at the surface in the Antarctic region.
#
# On Spartan, these fields live at the following location:
#
# ```
# /scratch/cs185c02/MITgcm/configurations/antarctica_temp/run/diags/TS_surf_daily_mean
# ```
#
# I will pick one of these at random and download it into my run directory. First, I will ensure the necessary directories are constructed:

# %%
os.makedirs(os.path.join(run_dir,'diags'), exist_ok=True)
os.makedirs(os.path.join(run_dir,'diags','TS_surf_daily_mean'), exist_ok=True)
os.makedirs(os.path.join(run_dir,'diags','EtaN_day_snap'), exist_ok=True)

# %% [markdown]
# Next, I will download one of the files at random with the following command:
#
# ```
# scp cs185c02@spartan03.sjsu.edu:/scratch/cs185c02/MITgcm/configurations/antarctica_temp/run/diags/TS_surf_daily_mean/TS_surf_daily_mean.0000017280.data .
# ```

# %% [markdown]
# ## Making a Plot
#
# With the data in hand, let's go ahead and make a quick plot. First, we will read in the data:

# %%
n_rows = 360
n_cols = 360
variables = ['THETA']
data = np.fromfile(os.path.join(run_dir,'diags','TS_surf_daily_mean','TS_surf_daily_mean.0000000060.data'),'>f4')
data = np.reshape(data,(len(variables),n_rows,n_cols))

# variables = ['ETAN']
# data = np.fromfile(os.path.join(run_dir,'diags','EtaN_day_snap','EtaN_day_snap.0000000012.data'),'>f4')
# data = np.reshape(data,(len(variables),n_rows,n_cols))

# %% [markdown]
# Next, let's make a plot:

# %%
plt.figure()
C = plt.pcolormesh(data[0,:,:],cmap='seismic', vmin=-25, vmax=25)
plt.colorbar(C)
plt.show()
